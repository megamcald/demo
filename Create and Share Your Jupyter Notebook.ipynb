# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Megam Calderón Luque** Graduate in Biology.

# %% [markdown]
# *I am interested in data science because I have seen that the field of data analysis is something necessary and emerging and I wanted to specialise in it. I think it is a very powerful tool for the world of conservation, which I am very passionate about.*

# %% [markdown]
# ### The code is going to perform a basic arithmetic operation of addition.

# %%
2+3
# Out:
# 5

# %% [markdown]
# 1. Step 1
# 2. Step 2
# 3. Step 3
#
# |Supply| Jenuary | February | March |
# |------|---------|:--------:|-----:|
# |Light ($) |20      |35      |25|
#
#
#
# ![image.png](attachment:image.png "foto de un perrito")
#
# [Link Puppy Pictures](https://www.google.com/search?q=perritos&rlz=1C1CHBF_esES1019ES1019&sxsrf=ALiCzsZKi8XEcUoq8xzb5GirAaDsstWjmQ:1669374072972&source=lnms&tbm=isch&sa=X&ved=2ahUKEwiWkveEl8n7AhW_SKQEHQkxAiIQ_AUoAXoECAIQAw&biw=1536&bih=746&dpr=1.25)
#
# >The puppy is very cute.
